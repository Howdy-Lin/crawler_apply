# %%
def record_data(elements):
    global i
    for element in elements:       
        element1 = element.find(class_='wordwidth').getText().strip()
        pics = element.find_all('img')
        image_links = [pic.get("src") for pic in pics]
        image_links ='https://shop.7-11.com.tw'+image_links[0]   
        dfimage.append(image_links)
        url1=image_links
        r=requests.get(url1)
        with open(f'./images/{i}'+'.jpg','wb') as f:
            f.write(r.content)
            i=i+1
        price = element.find("b").getText().strip()
        dfname.append(element1)
        dfprice.append(price)
        if('】'in element1)==True:
            element1=element1.split('】')
            name=element1[1]
            fac=element1[0]
            fac=''.join(fac)
            fac=fac.split('【')
            fac=fac[1]        
            dffac.append(fac)
            if ('濕式' in name)==True:
                categ = name.partition('濕式')
                categ = list(categ)
                print(categ[1])
                dfcateg.append(categ[1])
            elif ('抽取' in name)==True:
                categ = name.partition('抽取')
                categ = list(categ)
                print(categ[1])
                dfcateg.append(categ[1])
            elif ('平版' in name)==True:
                categ = name.partition('平版')
                categ = list(categ)
                print(categ[1])
                dfcateg.append(categ[1])
            elif ('捲筒' in name)==True:
                categ = name.partition('捲筒')
                categ = list(categ)
                print(categ[1])
                dfcateg.append(categ[1])
            else:
                dfcateg.append('')
        else:
            fac=''
            dffac.append('')
            dfcateg.append('')
    for good in goods:
        if ('衛生紙'in good['href'])==False:        
            dfgoods.append('https://shop.7-11.com.tw/shop/'+good['href'])
            print('https://shop.7-11.com.tw/shop/'+good['href'])          
    print(len(dfgoods))

# %%
# 載入需要的套件
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os
dfname=[]
dffac=[]
dfcateg=[]
dfprice=[]
dfimage=[]
dfgoods=[]
i=1
# 開啟瀏覽器視窗(Chrome)
# 方法一：執行前需開啟chromedriver.exe且與執行檔在同一個工作目錄
driver = webdriver.Chrome()
driver.get("https://shop.7-11.com.tw/shop/rui001.faces") # 更改網址以前往不同網頁
# 定位搜尋框
element = driver.find_element_by_class_name('ac_input')
# 傳入字串
element.send_keys('衛生紙')
element.send_keys(Keys.ENTER)
url = BeautifulSoup(driver.page_source, 'html.parser')   #抓下當前使用網址的html
goods = url.find_all(class_='headT')
catalog = url.find(class_='pagelist1')
next_page = catalog.find_all('a')   #抓含有下一頁超連結的element

elements = url.find_all(class_='prodM')

next_page=str(next_page)
while  ('下一頁'in next_page)==True:
    
    record_data(elements)
    
   # print(title1,title2)
    catalog = url.find(class_='pagelist1')
    next_page = catalog.find_all('a',string='下一頁')   #抓含有下一頁超連結的element
    print(next_page)
    for href in next_page:            #要用for迴圈才可取得next_page裡的element
        url = href.get('href')
        driver.get(url)
        url = BeautifulSoup(driver.page_source, 'html.parser')   #抓下當前使用網址的html
        elements = url.find_all(class_='prodM')  
        goods = url.find_all(class_='headT')
    url = BeautifulSoup(driver.page_source, 'html.parser')   #抓下當前使用網址的html
    catalog = url.find(class_='pagelist1')
    next_page = catalog.find_all('a',string='下一頁')   #抓含有下一頁超連結的element
    next_page = str(next_page)   #建立新的next_page 讓while迴圈可以繼續跑
    
record_data(elements)  #抓取最後一頁的資料
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel
# https://shop.7-11.com.tw/shop/rui005.faces?ID=210600012395
# https://shop.7-11.com.tw/shop/rui005.faces?ID=210600012403
# https://shop.7-11.com.tw/shop/rui005.faces?ID=210600012421
# 40
# [<a href="https://shop.7-11.com.tw/shop/rui009.faces?qs=%E8%A1%9B%E7%94%9F%E7%B4%99&amp;pageNo=2&amp;sort=1&amp;range=&amp;price=&amp;arrival_way_24h=&amp;pdate=&amp;pageSize=40">下一頁</a>]
# 抽取
# 抽取
# 抽取
# 平版
# 抽取
# 抽取
# 抽取
# 抽取
# 抽取
# 抽取
# 抽取
# 抽取
# https://shop.7-11.com.tw/shop/rui005.faces?ID=210600012430
# https://shop.7-11.com.tw/shop/rui005.faces?ID=210300014771
# https://shop.7-11.com.tw/shop/rui005.faces?ID=210300014780
# https://shop.7-11.com.tw/shop/rui005.faces?ID=210300014799
# https://shop.7-11.com.tw/shop/rui005.faces?ID=210300014807
# https://shop.7-11.com.tw/shop/rui005.faces?ID=210200004899
# https://shop.7-11.com.tw/shop/rui005.faces?ID=200700080679
# https://shop.7-11.com.tw/shop/rui005.faces?ID=200500134408
# https://shop.7-11.com.tw/shop/rui005.faces?ID=200200134129
# https://shop.7-11.com.tw/shop/rui005.faces?ID=191200034049
# https://shop.7-11.com.tw/shop/rui005.faces?ID=191000049025
# https://shop.7-11.com.tw/shop/rui005.faces?ID=190300114950
# https://shop.7-11.com.tw/shop/rui005.faces?ID=190300077862
# https://shop.7-11.com.tw/shop/rui005.faces?ID=181200059079
# https://shop.7-11.com.tw/shop/rui005.faces?ID=181200059114
# https://shop.7-11.com.tw/shop/rui005.faces?ID=180900014672
# https://shop.7-11.com.tw/shop/rui005.faces?ID=180700000767
# https://shop.7-11.com.tw/shop/rui005.faces?ID=180400035444
# https://shop.7-11.com.tw/shop/rui005.faces?ID=161200183675
# https://shop.7-11.com.tw/shop/rui005.faces?ID=160800149402
# 60

# %%
#寫入csv
import pandas as pd            
print(len(dfname))
print(len(dffac))
print(len(dfcateg))
print(len(dfprice))
print(len(dfimage))
dict = {'品名':dfname,'品牌':dffac,'種類':dfcateg,'價格':dfprice,'圖片':dfimage,'網址':dfgoods}
print(dict)

df = pd.DataFrame(dict) 
df.to_csv('reptile711.csv')
# Out:
# 60
# 60
# 60
# 60
# 60
# {'品名': ['【舒潔】女性專用濕式衛生紙10抽／包(2入)', '【舒潔】女性專用濕式衛生紙10抽', '【春風】超細柔抽取式衛生紙110抽72包*2箱組+抽取衛生紙6包隨機', '多用途防水衛生紙置物盒', 'Kleenex 舒潔-Baby Soft頂級3層舒適抽取衛生紙100抽x24包', 'MAY FLOWER 五月花 頂級妙用綿柔抽取衛生紙-輕巧包130抽X36包', 'Kirkland Signature 科克蘭 三層抽取衛生紙 120抽x24包', '【春風】超細柔抽取式衛生紙110抽x24包x3串+抽取衛生紙6包', 'Kirkland Signature 科克蘭 捲筒衛生紙', '【春風】超細柔�